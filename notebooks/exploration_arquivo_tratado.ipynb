# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/amazon_tratado.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   produto             1462 non-null   str
#  1   codigo              1462 non-null   str
#  2   categoria           1462 non-null   str
#  3   tipo_produto        1462 non-null   str
#  4   preco_desconto      1462 non-null   float64
#  5   perc_desconto       1462 non-null   float64
#  6   avaliacao           1462 non-null   float64
#  7   qtd_avaliacoes      1462 non-null   float64
#  8   valor_total_vendas  1462 non-null   float64
# dtypes: float64(5), str(4)
# memory usage: 331.8 KB

# %%
df.isnull().sum()
# Out:
# produto               0
# codigo                0
# categoria             0
# tipo_produto          0
# preco_desconto        0
# perc_desconto         0
# avaliacao             0
# qtd_avaliacoes        0
# valor_total_vendas    0
# dtype: int64

# %%
pd.set_option("display.max_columns", None)
df.head()
# Out:
#                                              produto      codigo  \
# 0  Wayona Nylon Braided USB To Lightning Fast Cha...  B07JW9H4J1
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...  B098NS6PVG
# 2  Sounce Fast Phone Charging Cable E Data Sync U...  B096MSW6CT
# 3  Boat Deuce USB 300 2 In 1 Type-C E Micro USB S...  B08HDJ86NZ
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...  B08CF3B7N1
#
#                  categoria tipo_produto  preco_desconto  perc_desconto  \
# 0  Computers e Accessories         Cabo           399.0           64.0
# 1  Computers e Accessories         Cabo           199.0           43.0
# 2  Computers e Accessories         Cabo           199.0           90.0
# 3  Computers e Accessories         Cabo           329.0           53.0
# 4  Computers e Accessories         Cabo           154.0           61.0
#
#    avaliacao  qtd_avaliacoes  valor_total_vendas
# 0        4.2         24269.0           9683331.0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(81)

# %%
df["avaliacao"].describe()
# Out:
# count    1462.000000
# mean        4.096717
# std         0.289497
# min         2.000000
# 25%         4.000000
# 50%         4.100000
# 75%         4.300000
# max         5.000000
# Name: avaliacao, dtype: float64

# %%
df["avaliacao"].unique()
# Out:
# array([4.2, 4. , 3.9, 4.1, 4.3, 4.4, 4.5, 3.7, 3.3, 3.6, 3.4, 3.8, 3.5,
#        4.6, 3.2, 5. , 4.7, 3. , 2.8, 3.1, 4.8, 2.3, 2. , 2.6, 2.9])
